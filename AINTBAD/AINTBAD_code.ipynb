# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/My Drive/Public/volume-dispersion/AINTBAD/
cwd = os.getcwd() # Get the current working directory
print("Current working directory: {0}\n\n".format(cwd))

# %run AINTBAD_CODE.py
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Public/volume-dispersion/AINTBAD
# Current working directory: /content/drive/My Drive/Public/volume-dispersion/AINTBAD
#
#
# The AINTBAD code obtains A, B in Equation (7) that better fits the target data.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/My Drive/Public/volume-dispersion/AINTBAD/AINTBAD_CODE.py in <module>
#      26 dir_list = os.listdir('./input'); check=False
#      27 while(check is False):
# ---> 28   file_name=input("\nEnter the file's name (file format is .txt, the 1st column is temperature and the second is fice): ")
#      29   check=file_name in dir_list
#      30   if check is False:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
