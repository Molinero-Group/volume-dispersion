# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/My Drive/Public/volume-dispersion/IPA/
cwd = os.getcwd() # Get the current working directory
print("Current working directory: {0}\n\n".format(cwd))

# %run IPA_CODE.py
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Public/volume-dispersion/IPA
# Current working directory: /content/drive/My Drive/Public/volume-dispersion/IPA
#
#
# The IPA code uses any parametrization for the nucleation rate and a size distribution to generate survival probability curves.
#
#  Step 1
#
# 1 - CNT parametrization from Qiu et. al 2019
# 2 - CNT parametrization from Koop and Murray 2016
# 3 - A and B from the AINTBAD model
